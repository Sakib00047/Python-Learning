# %%
import pandas as pd
import numpy as np

# %%
student_data={"Name":["Sakib","Momin","kawsar","Sakiba","Mominul","kawsary"],
              "Age":[24,25,26,24,25,26],
              "Dept":["URP","ME","CE","CSE","EEE","GCE"],
              "Score":[63,80,90,63,80,90],
             "Grad. year":[2026,2025,2024,2026,2025,2024],
             "Schoolarship":[False,True,False,False,True,False]}
a=pd.DataFrame(student_data)
display(a)
# Out:
#       Name  Age Dept  Score  Grad. year  Schoolarship
# 0    Sakib   24  URP     63        2026         False
# 1    Momin   25   ME     80        2025          True
# 2   kawsar   26   CE     90        2024         False
# 3   Sakiba   24  CSE     63        2026         False
# 4  Mominul   25  EEE     80        2025          True
# 5  kawsary   26  GCE     90        2024         False

# %%
student_data={"Name":["Sakib","Momin","kawsar","Sakiba","Mominul","kawsary"],
              "Age":[24,25,26,np.nan,25,26],
              "Dept":["URP","ME","CE","CSE",np.nan,"GCE"],
              "Score":[63,80,90,63,80,90],
             "Grad. year":[2026,2025,np.nan,2026,np.nan,2024],
             "Schoolarship":[False,True,False,False,True,False]}
a=pd.DataFrame(student_data)
display(a)
# Out:
#       Name   Age Dept  Score  Grad. year  Schoolarship
# 0    Sakib  24.0  URP     63      2026.0         False
# 1    Momin  25.0   ME     80      2025.0          True
# 2   kawsar  26.0   CE     90         NaN         False
# 3   Sakiba   NaN  CSE     63      2026.0         False
# 4  Mominul  25.0  NaN     80         NaN          True
# 5  kawsary  26.0  GCE     90      2024.0         False

# %%
##Excell theke file import deewa ba read kmne korbo
file_path="D:\Lec05.xlsx"
data=pd.read_excel(file_path)
display(data)
# Out:
#    Unnamed: 0     Name   Age Dept  Score  Grad. year  Schoolarship
# 0           0    Sakib  24.0  URP     63      2026.0         False
# 1           1    Momin  25.0   ME     80      2025.0          True
# 2           2   kawsar  26.0   CE     90         NaN         False
# 3           3   Sakiba   NaN  CSE     63      2026.0         False
# 4           4  Mominul  25.0  NaN     80         NaN          True
# 5           5  kawsary  26.0  GCE     90      2024.0         False

# %%
##ekhnn a r dara data k force dia string bujano hosse path er

file_path=r"D:\1907047_Sakib\Lec05.xlsx"
data=pd.read_excel(file_path)
display(data)
# Out:
#    Unnamed: 0     Name   Age Dept  Score  Grad. year  Schoolarship
# 0           0    Sakib  24.0  URP     63      2026.0         False
# 1           1    Momin  25.0   ME     80      2025.0          True
# 2           2   kawsar  26.0   CE     90         NaN         False
# 3           3   Sakiba   NaN  CSE     63      2026.0         False
# 4           4  Mominul  25.0  NaN     80         NaN          True
# 5           5  kawsary  26.0  GCE     90      2024.0         False

# %%
file_path=r"C:\Users\IOT\Desktop\SAKIB_1907047\Lecture_05.xlsx"
data=pd.read_excel(file_path)
display(data)
# Out:
#    Unnamed: 0     Name   Age Dept  Score  Grad. year  Schoolarship
# 0           0    Sakib  24.0  URP     63      2026.0         False
# 1           1    Momin  25.0   ME     80      2025.0          True
# 2           2   kawsar  26.0   CE     90         NaN         False
# 3           3   Sakiba   NaN  CSE     63      2026.0         False
# 4           4  Mominul  25.0  NaN     80         NaN          True
# 5           5  kawsary  26.0  GCE     90      2024.0         False

# %%
## data modified kora . data k excell file a write korbo

data_modified=data[["Name","Age","Score"]]
display(data_modified)
data_modified.to_excel(r"C:\Users\IOT\Desktop\SAKIB_1907047\New_Lect_05.xlsx")
# Out:
#       Name   Age  Score
# 0    Sakib  24.0     63
# 1    Momin  25.0     80
# 2   kawsar  26.0     90
# 3   Sakiba   NaN     63
# 4  Mominul  25.0     80
# 5  kawsary  26.0     90

# %%
## ekhan a data k scailing korbo sutro dia

data_modified_norm=(data_modified-data_modified.min())/(data_modified.max()-data_modified.min())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...

# %%
data_modified_norm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data_modified_norm
#
# NameError: name 'data_modified_norm' is not defined

# %%
## scaling korba ekta built in fuction dia korba r ekta 

df_score= data_modified["Score"]
df_score
# Out:
# 0    63
# 1    80
# 2    90
# 3    63
# 4    80
# 5    90
# Name: Score, dtype: int64

# %%
df_score_norm_a=(df_score-df_score.min())/(df_score.max()-df_score.min())
df_score_norm_a
# Out:
# 0    0.00000
# 1    0.62963
# 2    1.00000
# 3    0.00000
# 4    0.62963
# 5    1.00000
# Name: Score, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
## minmax scaler function babohar kore data k normalize kora

df_score_norm_b= MinMaxScaler().fit_transform("Score")
df_score_norm_b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 3
#       1 ## minmax scaler function babohar kore data k normalize kora
# ----> 3 df_score_norm_b= MinMaxScaler().fit_transform("Score")
#       4 df_score_norm_b
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# ...
